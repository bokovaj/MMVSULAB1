# %% [markdown]
# <a href="https://colab.research.google.com/github/bokovaj/MMVSULAB1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторная 2

# %%
import matplotlib.pyplot as plt 
import pandas as pd
from scipy.integrate import odeint 


data = {'Year': [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,2001,2002,2003,2004,2005],
        'Population': [5007469, 4986405, 4942891, 4881563, 4845407, 4820213, 4806641, 4783982, 4770897, 4741923, 4714844, 4688414, 4656474 ,4662038, 4686491]}
df = pd.DataFrame(data)

plt.plot(df['Year'], df['Population'])

plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population of Saint Petersburg since 1991')

plt.show()
