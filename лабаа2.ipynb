# %% [markdown]
# <a href="https://colab.research.google.com/github/bokovaj/MMVSULAB1/blob/main/%D0%BB%D0%B0%D0%B1%D0%B0%D0%B02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторная 2

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint


x = [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
y= [5007469, 4986405, 4942891, 4881563, 4845407, 4820213, 4806641, 4783982, 4770897, 4741923, 4714844, 4688414, 4656474, 4662038, 4686491   ]
plt.plot(x, y)
plt.grid(True)
plt.title('Численность населения г.Санкт-Петербург', fontsize=13)
# Out:
# Text(0.5, 1.0, 'Численность населения г.Санкт-Петербург')

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def dydt(x,t):
  k = -0.0044
  return k*x
t = [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
solve = odeint(dydt, 5007469, t=t)
solve = solve.flatten()
# %matplotlib inline 
v = [5007469, 4986405, 4942891, 4881563, 4845407, 4820213, 4806641, 4783982, 4770897, 4741923, 4714844, 4688414, 4656474, 4662038, 4686491   ]
plt.plot(t, solve, label = r"x′=kx")
plt.plot(t, v, label = r"Население г.Санкт-Петербург ") 
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
a=-99000
b=1
def dydt(x,t):
  return k(x)*x*(-0.00455)
def k(x):
  return a/x+b
t = [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
solve = odeint(dydt, 5007469, t=t)
solve = solve.flatten()
# %matplotlib inline 
v = [5007469, 4986405, 4942891, 4881563, 4845407, 4820213, 4806641, 4783982, 4770897, 4741923, 4714844, 4688414, 4656474, 4662038, 4686491   ]
plt.plot(t, solve, label = r"x'=k(x)*x")
plt.plot(t, v, label = r"Население Санкт-Петербург")
plt.grid(True)
plt.legend()
plt.show()
