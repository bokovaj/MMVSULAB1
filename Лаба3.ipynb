# %% [markdown]
# <a href="https://colab.research.google.com/github/bokovaj/MMVSULAB1/blob/main/%D0%9B%D0%B0%D0%B1%D0%B03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторная 3

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import odeint
url = 'https://raw.githubusercontent.com/bokovaj/MMVSULAB1/main/spb.csv'
df = pd.read_csv(url)
print(df)
Years = np.array(df['Years'])
Population = np.array(df['Population'])
def dydt(Years,Population):
  k = 0.0044
  return k*Years

plt.plot(Years, Population)
plt.grid(True)
plt.title('Численность населения г. Санкт_Петербург', fontsize=13)
# Out:
#     Years Population
# 0    1991  5 007 469
# 1    1992  4 986 405
# 2    1993  4 942 891
# 3    1994  4 881 563
# 4    1995  4 845 407
# 5    1996  4 820 213
# 6    1997  4 806 641
# 7    1998  4 783 982
# 8    1999  4 770 897
# 9    2000  4 741 923
# 10   2001  4 714 844
# 11   2002  4 688 414
# 12   2003  4 656 474
# 13   2004  4 662 038
# 14   2005  4 686 491
# 15   2006  4 712 854
# 16   2007  4 747 550
# 17   2008  4 764 864
# 18   2009  4 798 713
# 19   2010  4 832 759
# 20   2011  4 899 344
# 21   2012  4 953 219
# 22   2013  5 028 000
# 23   2014  5 131 942
# 24   2015  5 191 690
# 25   2016  5 225 690
# 26   2017  5 281 579
# 27   2018  5 351 935
# 28   2019  5 383 890
# 29   2020  5 383 900
# 30   2021  5 384 500
# 31   2022  5 387 800
# Text(0.5, 1.0, 'Численность населения г. Санкт_Петербург')
